# %% [markdown]
# # Matplotlib

# %% [markdown]
# ## Introdução
# Seja bem-vindo ao nosso guia sobre **Matplotlib**! Matplotlib é uma incrível biblioteca de **visualização de dados** em **Python**, amplamente utilizada para criar **diversos tipos de gráficos**. Com ela, podemos explorar visualmente padrões e tendências nos nossos dados de forma prática e eficaz.
#
# A **simplicidade** e a **versatilidade** dessa biblioteca fazem dela uma ferramenta indispensável para qualquer análise exploratória ou apresentação de resultados.
#
# Neste tutorial, vamos mergulhar nas **funcionalidades básicas**, entender os **conceitos fundamentais** e mostrar como você pode começar a criar suas próprias visualizações de dados.

# %% [markdown]
# ## Primeiros Passos - Instalação e Importação

# %% [markdown]
# Antes de mergulharmos no mundo fantástico da Matplotlib, precisamos garantir que ela esteja instalada no seu ambiente de trabalho. Para isso, execute o seguinte comando:

# %%
#!pip install -U matplotlib

# %% [markdown]
# Após a instalação ser concluída, o próximo passo é importar a biblioteca para que possamos iniciar a criação das nossas visualizações.

# %%
# Importando Matplotlib
import matplotlib

# Mostrando a versão atual do Matplotlib instalada
print(matplotlib.__version__)
# Out:
# 3.7.1

# %% [markdown]
# Neste guia, focaremos na visualização de dados usando a interface simplificada `pyplot`.

# %%
# Importando o módulo pyplot
import matplotlib.pyplot as plt

# %% [markdown]
# Vamos adotar o padrão amplamente utilizado na comunidade Python, que é importar `pyplot` com o apelido **`plt`**. Esse hábito ajuda a manter nosso código limpo e fácil de entender.

# %% [markdown]
# Matplotlib se integra perfeitamente com outras bibliotecas como `NumPy` e `Pandas`, o que facilita a manipulação e visualização de grandes volumes de dados. Para seguirmos em frente, vamos também importar a biblioteca `NumPy`, essencial para muitas operações com dados.

# %%
# Importando a biblioteca Numpy
import numpy  as np

# %% [markdown]
# ## Primeiro Gráfico - Títulos e Rótulos
#
# Pronto para o nosso "Hello World" no mundo da visualização de dados? 😃 Com as bibliotecas já importadas, vamos criar nosso primeiro gráfico de linha.

# %%
# Criando dois arrays de dados
x = [1, 2, 3, 4, 5, 6, 7, 8]
y = [2, 3, 5, 6, 8, 9, 11, 12]

# Gerando o gráfico de linha com plt.plot
plt.plot(x, y)

# Adicionando rótulo ao Eixo X
plt.xlabel("Eixo X")

# Adicionando rótulo ao Eixo Y
plt.ylabel("Eixo Y")

# Definindo o título do gráfico
plt.title("Meu primeiro gráfico")

# Exibindo o gráfico
plt.show()

# %% [markdown]
# ## Figuras e Eixos
# Entender a diferença entre figuras e eixos é essencial para criar e organizar gráficos mais complexos.
#
# - **Figura:** É a janela ou área onde todos os gráficos são desenhados. Uma figura pode conter múltiplos eixos, ou seja, podemos criar mais de um gráfico em uma única janela.
#
# - **Eixo:** É a área de plotagem individual dentro de uma figura onde os dados são desenhados. Cada eixo contém um gráfico distinto.
#
# - **Subplots:** O método `plt.subplots()` é usado para criar uma nova figura com um ou mais eixos. Ele retorna dois objetos:
#   - **fig:** Representa a figura que contém todos os eixos.
#   - **ax:** Refere-se ao(s) eixo(s) onde os gráficos serão desenhados. `ax` é frequentemente utilizado para referenciar e modificar o conteúdo dos eixos.

# %%
# Criando uma nova figura e um eixo
fig, ax = plt.subplots()

# Mostrando a figura criada
print(f"Figura: {fig}")

# Mostrando os eixos criados
print(f"Eixos: {ax}")
# Out:
# Figura: Figure(640x480)
# Eixos: Axes(0.125,0.11;0.775x0.77)

# %%
# Criando uma nova figura e um eixo
fig, ax = plt.subplots()

# Plotando o gráfico de linha no eixo ax
ax.plot(x, y)

# Adicionando rótulo ao Eixo X
ax.set_xlabel("Eixo X")

# Adicionando rótulo ao Eixo Y
ax.set_ylabel("Eixo Y")

# Definindo o título do gráfico
ax.set_title("Gráfico Personalizado")

# Exibindo o gráfico
plt.show()

# %% [markdown]
# No exemplo anterior, usamos o método `plt.subplots()` sem argumentos, o que resultou em uma figura com um único eixo, pois ele assumiu os valores padrão. Agora, vamos explorar mais sobre esse método.

# %%
# Definindo os dados
x = ["Grupo A", "Grupo B", "Grupo C"]
y = [20, 40, 60]

# Criando uma figura com dois eixos
# Exibindo dois gráficos, lado a lado, em uma única figura
fig, ax = plt.subplots(1, 2)

# Ajustando o espaçamento horizontal entre os gráficos
fig.subplots_adjust(wspace=0.5)  # wspace = Width Space (espaço horizontal)

# Plotando o gráfico de linha no primeiro eixo
ax[0].plot(x, y)

# Plotando o gráfico de barra no segundo eixo
ax[1].bar(x, y)

# Adicionando títulos aos gráficos
ax[0].set_title("Gráfico de Linha")
ax[1].set_title("Gráfico de Barra")

# Exibindo os gráficos
plt.show()

# %%
# Criando duas figuras com um eixo
# Exibindo dois gráficos, um abaixo do outro, em duas figuras diferentes
fig, ax = plt.subplots(2, 1)

# Ajustando o espaçamento vertical entre os gráficos
fig.subplots_adjust(hspace=0.5)  # hspace = Height Space (espaço vertical)

# Plotando o gráfico de linha no primeiro eixo
ax[0].plot(x, y)

# Plotando o gráfico de barra no segundo eixo
ax[1].bar(x, y)

# Adicionando títulos aos gráficos
ax[0].set_title("Gráfico de Linha")
ax[1].set_title("Gráfico de Barra")

# Exibindo os gráficos
plt.show()

# %% [markdown]
# Nos exemplos anteriores, usamos o método `plt.subplots()` para criar uma figura com dois eixos, resultando em dois gráficos lado a lado. Também criamos duas figuras separadas, cada uma com um eixo, resultando em dois gráficos um abaixo do outro.
#
# Podemos personalizar a quantidade de figuras e eixos conforme as nossas necessidades.

# %% [markdown]
# Mas o que acontece se tentarmos gerar dois gráficos sem especificar a quantidade de figuras e eixos?

# %%
# Definindo os dados
x  = ["Grupo A", "Grupo B", "Grupo C"]
y1 = [20, 40, 60]
y2 = [15, 30, 65]

# Plotando os gráficos de linha
plt.plot(x, y1)
plt.plot(x, y2)

# Adicionando o título ao gráfico
plt.title("Gráficos Sobrepostos")

# Exibindo os gráficos
plt.show()

# %% [markdown]
# **Os gráficos ficarão sobrepostos!** Lembre-se dessa informação, ela pode ser útil ao criar gráficos de sazonalidade no futuro.

# %% [markdown]
# ## Redimensionamento de Figuras e Ajuste de layout
# Você deve ter notado que todas nossas figuras até agora seguiram um tamanho padrão (640x480 pixels). Contudo, ao trabalhar com visualizações de dados é comum precisar ajustar o tamanho da figura e garantir que os subplots não se sobreponham, proporcionando uma apresentação mais clara dos dados. Para isso, utilizamos o parâmetro `figsize` e a função `tight_layout`.

# %% [markdown]
# ### Redimensionamento de Figuras (`figsize`)
#
# O parâmetro `figsize` permite definir o tamanho da figura em polegadas, ajustando a largura e a altura conforme necessário. Ele é passado como um argumento nas funções `plt.figure()`e `plt.subplots()`.
#
# A sintaxe básica é `figsize=(largura, altura)`

# %%
# Definindo os dados
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 6, 8]

# Criando uma nova figura e um eixo com tamanho 5x3 polegadas
fig, ax = plt.subplots(figsize=(5, 3))

# Plotando o gráfico de linha
ax.plot(x, y)

# Adicionando o título ao gráfico
ax.set_title("Gráfico Redimensionado")

# Exibindo o gráfico
plt.show()

# Mostrando a figura criada
print(f"Figura: {fig}")
# Out:
# Figura: Figure(500x300)

# %% [markdown]
# ### Ajuste de layout (`tight_layout`)
#
# O método `tight_layout` é extremamente útil para ajustar automaticamente os parâmetros dos subplots, evitando sobreposições entre elementos como rótulos, títulos e legendas. Isso é especialmente importante quando trabalhamos com múltiplos subplots em uma única figura.

# %% [markdown]
# **Exemplo sem `tight_layout`**

# %%
# Definindo os dados
x  = [1, 2, 3, 4, 5, 6]
y1 = [1, 1, 2, 2, 3, 3]
y2 = [0, 1, 0, 2, 0, 3]

# Criando duas figuras com um eixo
fig, ax = plt.subplots(2, 1)

# Plotando o gráfico de linha no primeiro eixo
ax[0].plot(x, y1)

# Plotando o gráfico de linha no segundo eixo
ax[1].plot(x, y2)

# Adicionando títulos aos gráficos
ax[0].set_title("Gráfico de Linha 01")
ax[1].set_title("Gráfico de Linha 02")

# Exibindo os gráficos
plt.show()

# %% [markdown]
# **Exemplo com `tight_layout`**

# %%
# Criando duas figuras com um eixo
fig, ax = plt.subplots(2, 1)

# Plotando o gráfico de linha no primeiro eixo
ax[0].plot(x, y1)

# Plotando o gráfico de linha no segundo eixo
ax[1].plot(x, y2)

# Adicionando títulos aos gráficos
ax[0].set_title("Gráfico de Linha 01")
ax[1].set_title("Gráfico de Linha 02")

# Ajustando o layout dos gráficos
fig.tight_layout()

# Exibindo os gráficos
plt.show()

# %% [markdown]
# ## Limites, Margens, Escalas e Marcações
# Na visualização de dados, é crucial saber como controlar os limites dos eixos, as margens e as escalas dos gráficos. Isso garante que as informações sejam interpretadas corretamente.

# %% [markdown]
# ### Limites dos Eixos (`xlim` e `ylim`)
#
# Os métodos `xlim` e `ylim` são usados para definir os limites dos eixos X e Y, respectivamente. Permitindo escolher o intervalo de valores que será exibido em cada eixo.

# %% [markdown]
# **Exemplo sem `xlim` e `ylim`**

# %%
# Definindo os dados
x = [10, 20, 30]
y = [23, 41, 57]

# Criando uma nova figura e um eixo
fig, ax = plt.subplots()

# Plotando o gráfico de linha
ax.plot(x, y)

# Adicionando rótulos aos eixos X e Y
ax.set_xlabel("Eixo X - Valores Padrões")
ax.set_ylabel("Eixo Y - Valores Padrões")

# Adicionando o título ao gráfico
ax.set_title("Gráfico de Linha - Padrão")

# Exibindo o gráfico
plt.show()

# %% [markdown]
# **Exemplo com `xlim` e `ylim`**

# %%
# Criando uma nova figura e um eixo
fig, ax = plt.subplots()

# Plotando o gráfico de linha
ax.plot(x, y)

# Adicionando rótulos aos eixos X e Y
ax.set_xlabel("Eixo X - Valores Personalizados")
ax.set_ylabel("Eixo Y - Valores Personalizados")

# Definindo o limite mínimo e máximo para o eixo X
ax.set_xlim(5, 35)

# Definindo o limite mínimo e máximo para o eixo Y
ax.set_ylim(20, 60)

# Adicionando o título ao gráfico
ax.set_title("Gráfico de Linha - Com Limites")

# Exibindo o gráfico
plt.show()

# %% [markdown]
# ### Margens (`plt.margins`)
# O método `plt.margins` é utilizado para adicionar margem ao redor dos dados no gráfico, ajustando o espaçamento entre os dados e as bordas da figura. Isso é útil para evitar que os dados fiquem muito próximos das bordas do gráfico, proporcionando uma visualização mais limpa e organizada.

# %% [markdown]
# **Exemplo com `plt.margins`**

# %%
# Criando uma figura com três eixos, com tamanho 15x4.8 polegadas
fig, ax = plt.subplots(1, 3, figsize=(15, 4.8))

# Plotando o gráfico de linha no primeiro eixo
ax[0].plot(x, y)
ax[0].set_xlabel("Eixo X - Valores Padrões")
ax[0].set_ylabel("Eixo Y - Valores Padrões")
ax[0].set_title("Sem Margens")

# Plotando o gráfico de linha no segundo eixo
ax[1].plot(x, y)
ax[1].set_xlabel("Eixo X - Valores Redefinidos")
ax[1].set_ylabel("Eixo Y - Valores Redefinidos")
ax[1].set_title("Com Margens = 0.5")

# Adicionando margens aos eixos X e Y no segundo gráfico
ax[1].set_xmargin(0.5)
ax[1].set_ymargin(0.5)

# Plotando o gráfico de linha no terceiro eixo
ax[2].plot(x, y)
ax[2].set_xlabel("Eixo X - Valores Redefinidos")
ax[2].set_ylabel("Eixo Y - Valores Redefinidos")
ax[2].set_title("Com Margens (X = 1.5 e Y = 2)")

# Adicionando margens aos eixos X e Y no terceiro gráfico
ax[2].set_xmargin(1.5)
ax[2].set_ymargin(2)

# Ajustando o layout dos gráficos
fig.tight_layout()

# Exibindo os gráficos
plt.show()

# %% [markdown]
# ### Escalas dos Eixos (`xscale` e `yscale`)
# Em um gráfico, as escalas determinam como os valores nos eixos são distribuídos e apresentados, influenciando diretamente a visualização e interpretação dos dados.
#
# Os métodos `xscale` e `yscale` são usados para alterar a escala dos eixos X e Y, respectivamente. O Matplotlib suporta várias escalas diferentes, cada tipo de escala **possui aplicações distintas**, dependendo do tipo de dados e das informações que se deseja destacar. A escolha adequada da escala pode ter um impacto significativo na compreensão dos dados e na clareza da apresentação visual.
#
# **Importante!** Ao criar um gráfico sem definir a escala, o Matplotlib assumirá automaticamente a escala linear.
#
# Para verificar a escala adotada em um eixo específico, utilize os comandos:
#
# ```python
# ax.xaxis.get_scale()  # Verifica a escala do eixo X
# ax.yaxis.get_scale()  # Verifica a escala do eixo Y
# ```

# %%
# Desativando warnings
import warnings
warnings.simplefilter("ignore")

# Definindo os dados
# Gerando 50 valores aleatórios de uma distribuição normal com média e desvio padrão 0.5
# Filtrando os valores entre 0 e 1 e ordenando em ordem crescente
y = np.random.normal(loc=0.5, scale=0.5, size=50)
y = np.sort(y[(y > 0) & (y < 1)])
x = np.arange(len(y))

# Definindo a lista de escalas e títulos correspondentes
escalas = [None, "linear", "log", "logit", "symlog", "asinh"]
titulos = ["Sem escala", "Linear", "Log", "Logit", "SymmetricalLog", "Asinh"]

# Criando duas figuras com três eixos, com tamanho 15x10 polegadas
fig, axs = plt.subplots(2, 3, figsize=(15, 10))

# Plotando gráficos de linha com as escalas correspondentes
for i, escala in enumerate(escalas):
    linha = i // 3
    coluna = i % 3

    axs[linha, coluna].plot(x, y)
    axs[linha, coluna].set_title(titulos[i])

    # Aplicando a escala ao eixo Y, se especificada
    if escala is not None:
        axs[linha, coluna].set_yscale(escala)

# Ajustando o layout dos gráficos
fig.tight_layout()

# Exibindo os gráficos
plt.show()

# %% [markdown]
# ### Marcações (`Ticks`)
# Os **ticks** são marcações nos eixos do gráfico que indicam valores de referência. Essas marcações podem ser numéricas ou categóricas e servem para destacar pontos específicos.
#
# Quando traçamos um gráfico, os eixos assumem ticks padrão, mas podemos personalizá-los utilizando os métodos `xticks` e `yticks`. Esses métodos permitem definir localizações específicas para as marcações nos eixos, bem como os rótulos exibidos nessas marcações.
#
# #### Personalização
# - **Definindo Localizações e Rótulos**: Utilize `plt.xticks([localizações], [rótulos])` ou `set_xticks([localizações], [rótulos])` para especificar onde os ticks serão posicionados e quais rótulos serão exibidos.
#
# - **Rotação dos Rótulos**: O parâmetro `rotation` permite girar os rótulos dos ticks para melhorar a legibilidade.
#
# - **Estilo**: Também é possível personalizar a aparência dos rótulos dos ticks com parâmetros como `fontsize` e `color`, o que torna o visual do gráfico mais atraente. Vamos explorar isso com mais detalhes na seção sobre **Personalização de Gráficos**.
#
# A personalização dos ticks contribui para a clareza e a precisão na comunicação visual das informações apresentadas no gráfico.

# %% [markdown]
# **Exemplo sem `xticks` e `yticks`**

# %%
# Definindo os dados
x = [8, 6, 4, 2, 0]
y = [1, 3, 5, 7, 9]

# Criando uma nova figura e um eixo
fig, ax = plt.subplots()

# Plotando o gráfico de linha no eixo ax
ax.plot(x, y)

# Adicionando rótulos aos eixos X e Y
ax.set_xlabel("Eixo X")
ax.set_ylabel("Eixo Y")

# Adicionando o título ao gráfico
ax.set_title("Gráfico (Sem Ticks Personalizados)")

# Ajustando o layout do gráfico
fig.tight_layout()

# Exibindo o gráfico
plt.show()

# %% [markdown]
# **Exemplo com `xticks` e `yticks`**

# %%
# Criando uma figura com três eixos, com tamanho 15x4.8 polegadas
fig, axs = plt.subplots(1, 3, figsize=(15, 4.8))

# Plotando o primeiro gráfico com ticks personalizados numéricos
axs[0].plot(x, y)
axs[0].set_title("Ticks Personalizados - Numéricos")
axs[0].set_xticks(x)  # Definindo ticks específicos para o eixo X
axs[0].set_yticks(y)  # Definindo ticks específicos para o eixo Y

# Plotando o segundo gráfico com ticks personalizados categóricos
categorias = ["A", "B", "C", "D", "E"]

axs[1].plot(x, y)
axs[1].set_title("Ticks Personalizados - Categóricos")
axs[1].set_xticks(np.sort(x))  # Definindo posições dos ticks no eixo X
axs[1].set_xticklabels(categorias, rotation=45) # Definindo rótulos para o eixo X
axs[1].set_yticks(y)  # Definindo posições dos ticks no eixo Y
axs[1].set_yticklabels([f"{tick} km" for tick in y])  # Definindo rótulos para o eixo Y

# Plotando o terceiro gráfico com ticks personalizados fixos
axs[2].plot(x, y)
axs[2].set_title("Ticks Personalizados - Valores Fixados")
axs[2].set_xticks([0, 10, 20])  # Definindo valores fixos para os ticks do eixo X
axs[2].set_yticks([0, 15, 30])  # Definindo valores fixos para os ticks do eixo Y

# Ajustando o layout dos gráficos
fig.tight_layout()

# Exibindo os gráficos
plt.show()

# %% [markdown]
# ## Subtítulos, Anotações e Legendas
# Adicionar subtítulos, anotações e legendas aos gráficos é super importante para deixar os dados mais claros e compreensíveis. Esses elementos ajudam a fornecer contexto, realçar detalhes e tornam mais fácil para o leitor interpretar o que está sendo mostrado.

# %% [markdown]
# ### Subtítulos (`plt.suptitle`)
# Para adicionar um título centralizado à figura, usamos a função `plt.suptitle()`. Essa função é usada para colocar um subtítulo geral quando você tem vários subplots na mesma figura.

# %%
# Definindo os dados
x = ["Grupo A", "Grupo B", "Grupo C"]
y = [20, 40, 60]

# Criando uma figura com dois eixos, com tamanho 10x4.8 polegadas
fig, ax = plt.subplots(1, 2, figsize=(10, 4.8))

# Plotando o gráfico de linha no primeiro eixo
ax[0].plot(x, y)
ax[0].set_title("Gráfico de Linha")

# Plotando o gráfico de barra no segundo eixo
ax[1].bar(x, y)
ax[1].set_title("Gráfico de Barra")

# Adicionando um subtítulo à figura
plt.suptitle("Exemplo de Subtítulo")

# Ajustando o layout dos gráficos
fig.tight_layout()

# Exibindo os gráficos
plt.show()

# %% [markdown]
# ### Anotações (`fig.text`)
# Se precisar colocar um texto em um local específico da figura, a função `fig.text()` é a solução! Ela permite posicionar o texto numa posição específica.

# %%
# Criando uma figura com dois eixos, com tamanho 10x4.8 polegadas
fig, ax = plt.subplots(1, 2, figsize=(10, 4.8))

# Plotando o gráfico de linha no primeiro eixo
ax[0].plot(x, y)
ax[0].set_title("Gráfico de Linha")

# Plotando o gráfico de barra no segundo eixo
ax[1].bar(x, y)
ax[1].set_title("Gráfico de Barra")

# Adicionando uma anotação à figura usando fig.text()
fig.text(
    0.5, # Definindo a posição horizontal da anotação
    0.95, # Definindo a posição vertical da anotação
    "Exemplo de Anotação com fig.text()", # Texto da anotação
    ha="center", # Centralizando o texto horizontalmente
    fontsize=12, # Definindo o tamanho da fonte
    color="blue", # Definindo a cor do texto
)

# Ajustando o layout dos gráficos
fig.tight_layout()

# Exibindo os gráficos
plt.show()

# %% [markdown]
# ### Anotações (`annotate`)
# A função `annotate()` é ideal para adicionar detalhes aos gráficos. Com ela, você pode incluir texto e setas que direcionam a atenção para pontos específicos, oferecendo explicações mais claras e contextuais.

# %%
# Definindo os dados
x = [1, 2, 3, 4, 5]
y = [1, 4, 9, 16, 25]

# Criando uma nova figura e um eixo
fig, ax = plt.subplots()

# Plotando o gráfico de linha
ax.plot(x, y)

# Adicionando rótulos aos eixos X e Y
ax.set_xlabel("Eixo X")
ax.set_ylabel("Eixo Y")

# Adicionando o título ao gráfico
ax.set_title("Gráfico com Anotação")

# Adicionando uma anotação com annotate()
ax.annotate(
    "Ponto Máximo", # Texto da anotação
    xy=(5, 25), # Coordenadas do ponto a ser anotado
    xytext=(3.5, 20), # Posição do texto da anotação
    arrowprops=dict(
        facecolor="red", # Definindo a cor da seta
        shrink=0.05 # Definindo o comprimento da seta
    )
)

# Exibindo o gráfico
plt.show()

# %% [markdown]
# ### Legendas (`plt.legend`)
# A função `plt.legend()` serve para adicionar uma legenda no gráfico. Ela é essencial para identificar e diferenciar os vários elementos gráficos, como linhas, barras ou outros marcadores presentes na visualização dos dados.

# %%
# Definindo os dados
x = ["Grupo A", "Grupo B", "Grupo C"]
y1 = [20, 40, 60]
y2 = [15, 30, 65]

# Criando uma nova figura e um eixo
fig, ax = plt.subplots()

# Plotando os gráficos de linha com rótulos para a legenda
ax.plot(x, y1, label="Dados 1")  # Definindo rótulo da primeira linha
ax.plot(x, y2, label="Dados 2")  # Definindo rótulo da segunda linha

# Adicionando o título ao gráfico
ax.set_title("Gráfico com Legenda A")

# Adicionando a legenda ao gráfico
ax.legend()

# Exibindo o gráfico
plt.show()

# %% [markdown]
# No gráfico acima, foi preciso usar uma nova propriedade ao plotar os dados: a propriedade `label`. Ela define os rótulos que aparecem na legenda. Veja uma maneira alternativa de definir esses rótulos abaixo:

# %%
# Criando uma nova figura e um eixo
fig, ax = plt.subplots()

# Plotando os gráficos de linha
ax.plot(x, y1)
ax.plot(x, y2)

# Adicionando o título ao gráfico
ax.set_title("Gráfico com Legenda B")

# Definindo rótulos para a legenda
ax.legend(["Dados 1", "Dados 2"])

# Exibindo o gráfico
plt.show()

# %% [markdown]
# #### Legendas Personalizadas
# Você também pode personalizar a posição e a aparência da legenda usando parâmetros adicionais na função `legend()`.

# %%
# Criando uma nova figura e um eixo
fig, ax = plt.subplots()

# Plotando os gráficos de linha
ax.plot(x, y1)
ax.plot(x, y2)

# Adicionando o título ao gráfico
ax.set_title("Gráfico com Legenda C")

# Adicionando a legenda com opções de personalização
ax.legend(
    ["Dados 1", "Dados 2"], # Definindo rótulos para a legenda
    loc="lower right", # Definindo a posição da caixa de legenda
    fontsize="small", # Definindo o tamanho da fonte dos rótulos
    title="Legenda", # Definindo o título da caixa de legenda
    title_fontsize="large", # Definindo o tamanho da fonte do título
)

# Exibindo o gráfico
plt.show()

# %% [markdown]
# ## Tipos de Gráficos
# O Matplotlib oferece uma ampla gama de funções para criar diversos tipos de gráficos, cada um adequado para visualizar diferentes tipos de dados. A seguir, apresentamos alguns dos principais gráficos que você pode criar com essa biblioteca.

# %% [markdown]
# ### Gráfico de Linhas (`plt.plot`)
# Ideal para exibir tendências ao longo do tempo ou relação entre variáveis contínuas.

# %%
# Definindo os dados
x = np.arange(0, 10, 0.1) # Gerando valores de x de 0 a 10 com intervalo de 0.1
y = np.sin(x) # Calculando o seno de x
z = np.cos(x) # Calculando o cosseno de x

# Plotando o gráfico de linha para o seno
plt.plot(x, y)
# Plotando o gráfico de linha para o cosseno
plt.plot(x, z)

# Adicionando o título ao gráfico
plt.title("Gráfico de Linhas")

# Exibindo o gráfico
plt.show()

# %% [markdown]
# ### Gráfico de Barras Verticais (`plt.bar`)
# Excelente para a comparação de quantidades entre diferentes categorias.

# %%
# Definindo os dados
x = ["A", "B", "C", "D"] # Categorias para o eixo X
y = [10, 20, 15, 25] # Valores para o eixo Y

# Plotando o gráfico de barras verticais
plt.bar(x, y)

# Adicionando o título ao gráfico
plt.title("Gráfico de Barras Verticais")

# Exibindo o gráfico
plt.show()

# %% [markdown]
# ### Gráfico de Barras Horizontais (`plt.barh`)
# Similar ao de barras verticais, mas com as barras orientadas horizontalmente.

# %%
# Definindo os dados
x = ["Categoria A",
     "Categoria B",
     "Categoria C",
     "Categoria D"] # Categorias para o eixo X
y = [10, 20, 15, 25] # Valores para o eixo Y

# Plotando o gráfico de barras horizontais
plt.barh(x, y)

# Adicionando o título ao gráfico
plt.title("Gráfico de Barras Horizontais")

# Exibindo o gráfico
plt.show()

# %% [markdown]
# ### Gráfico de Dispersão (`plt.scatter`)
# Usado para visualizar a relação entre duas variáveis contínuas, mostrando pontos no plano cartesiano.

# %%
# Definindo os dados
x = np.random.rand(50) # Gerando 50 valores aleatórios para o eixo X
y = np.random.rand(50) # Gerando 50 valores aleatórios para o eixo Y

# Plotando o gráfico de dispersão
plt.scatter(x, y)

# Adicionando o título ao gráfico
plt.title("Gráfico de Dispersão")

# Exibindo o gráfico
plt.show()

# %% [markdown]
# ### Histograma (`plt.hist`)
# Mostra a distribuição de dados em forma de barras, útil para entender a frequência de ocorrência de valores.

# %%
# Definindo os dados
data = np.random.randn(1000) # Gerando 1000 valores aleatórios com distribuição normal

# Plotando o histograma
plt.hist(data, bins=10) # Dividindo os dados em 10 intervalos

# Adicionando o título ao gráfico
plt.title("Histograma")

# Exibindo o gráfico
plt.show()

# %% [markdown]
# ### Diagrama de Caixa (`plt.boxplot`)
# Fornece uma visão da distribuição dos dados através de quartis, identificando outliers e variabilidade.

# %%
# Definindo os dados
data = np.random.randn(500) # Gerando 500 valores aleatórios com distribuição normal

# Plotando o diagrama de caixa
plt.boxplot(data)

# Adicionando o título ao gráfico
plt.title("Diagrama de Caixa")

# Exibindo o gráfico
plt.show()

# %% [markdown]
# ### Gráfico de Pizza (`plt.pie`)
# Utilizado para mostrar a composição de um conjunto de dados categorizados, mostrando proporções em um círculo.

# %%
# Definindo os dados
rotulos = ["Grupo A", "Grupo B", "Grupo C"] # Rótulos para cada fatia da pizza
tamanhos = [35, 45, 20] # Tamanhos das fatias da pizza

# Plotando o gráfico de pizza
plt.pie(tamanhos, labels=rotulos, autopct="%1.1f%%")

# Adicionando o título ao gráfico
plt.title("Gráfico de Pizza")

# Exibindo o gráfico
plt.show()

# %% [markdown]
# ### Exibição de Imagens (`plt.imshow`)
# Utilizado para mostrar imagens em forma de grade de pixels.

# %%
# Definindo os dados
img = np.random.randint(5, 500, (15, 15)) # Gerando uma matriz 15x15 com valores inteiros aleatórios entre 5 e 500

# Plotando a imagem
plt.imshow(img)

# Adicionando o título ao gráfico
plt.title("Exibição de Imagens")

# Exibindo o gráfico
plt.show()

# %% [markdown]
# ### Gráfico de Barras de Erro (`plt.errorbar`)
# Usado para representar graficamente a variabilidade dos dados, mostrando barras que indicam a faixa de incerteza.

# %%
# Definindo os dados
x = [0, 1, 2, 3, 4, 5] # Valores para o eixo X
y = [0, 2, 4, 6, 8, 10] # Valores para o eixo Y
yerro = [0, 1.9, 2.8, 3.7, 4.6, 5.5] # Erros associados a cada ponto

# Plotando o gráfico de barras de erro
plt.errorbar(x, y, yerr=yerro, fmt="o")

# Adicionando o título ao gráfico
plt.title("Gráfico de Barras de Erro")

# Exibindo o gráfico
plt.show()

# %% [markdown]
# ### Gráfico de Área Empilhada (`plt.stackplot`)
# Utilizado para exibir várias séries de dados como áreas empilhadas umas sobre as outras.

# %%
# Definindo os dados
a = np.linspace(1, 10, 10)
b = np.sort(np.random.randint(low=1, high=11, size=10))
c = np.sort(np.random.randint(low=2, high=12, size=10))
d = np.sort(np.random.randint(low=3, high=13, size=10))

# Plotando o gráfico de área empilhada
plt.stackplot(a, b, c, d)

# Adicionando o título ao gráfico
plt.title("Gráfico de Área Empilhada")

# Adicionando a legenda
plt.legend(
    ["Dados 1", "Dados 2", "Dados 3"], loc="upper left"
)  # Definindo rótulos para a legenda e a posição

# Exibindo o gráfico
plt.show()

# %% [markdown]
# ## Personalização de Gráficos
# Personalizar gráficos é uma habilidade essencial para qualquer analista de dados. Além de deixar os gráficos mais atraentes, a personalização torna as informações mais compreensíveis. Com esses ajustes, você pode realçar pontos importantes, melhorar a legibilidade e adaptar o gráfico para o público ou o contexto da apresentação.

# %% [markdown]
# ### Grids
#
# Grids são linhas horizontais e verticais que atravessam o gráfico, facilitando a visualização e interpretação dos dados. Elas fornecem uma referência visual que ajuda a ler valores específicos e a comparar diferentes pontos de dados com mais facilidade.

# %%
# Definindo os dados
x = [1, 2, 3, 4, 5, 6, 7, 8]
y = [2, 3, 5, 6, 8, 9, 11, 12]

# Criando uma nova figura e um eixo
fig, ax = plt.subplots()

# Plotando o gráfico de linha
ax.plot(x, y)

# Adicionando rótulos aos eixos X e Y
ax.set_xlabel("Eixo X")
ax.set_ylabel("Eixo Y")

# Adicionando o título ao gráfico
ax.set_title("Gráfico com Grid Padrão")

# Exibindo o grid padrão
ax.grid()

# Exibindo o gráfico
plt.show()

# %% [markdown]
# Existem várias formas de personalizar os grids de um gráfico. Você pode optar por exibir as linhas apenas em um dos eixos, ajustar a espessura, a cor e o estilo das linhas. As opções são bastante variadas!

# %%
# Definindo os dados
x = [1, 2, 3, 4, 5, 6, 7, 8]
y = [2, 3, 5, 6, 8, 9, 11, 12]

# Criando uma figura com quatro eixos - tamanho 15x4.8 polegadas
fig, ax = plt.subplots(1, 4, figsize=(15, 4.8))

# Grid apenas no Eixo X
ax[0].plot(x, y)
ax[0].set_xlabel("Eixo X")
ax[0].set_ylabel("Eixo Y")
ax[0].set_title("Grid apenas no Eixo X")
ax[0].grid(axis="x") # Ativando o grid apenas no eixo X

# Grid com estilo de linha
ax[1].plot(x, y)
ax[1].set_xlabel("Eixo X")
ax[1].set_ylabel("Eixo Y")
ax[1].set_title("Grid com estilo de linha")
ax[1].grid(linestyle=":") # Definindo o estilo da linha do grid como pontilhado

# Grid com linha mais espessa
ax[2].plot(x, y)
ax[2].set_xlabel("Eixo X")
ax[2].set_ylabel("Eixo Y")
ax[2].set_title("Grid com linha mais espessa")
ax[2].grid(linewidth=1.8) # Ajustando a espessura da linha do grid

# Grid com cor
ax[3].plot(x, y)
ax[3].set_xlabel("Eixo X")
ax[3].set_ylabel("Eixo Y")
ax[3].set_title("Grid com Cor")
ax[3].grid(color="Blue") # Definindo a cor do grid como azul

# Ajustando o layout
fig.tight_layout()

# Exibindo os gráficos
plt.show()

# %% [markdown]
# ### Spines
# Spines são as bordas que **delimitam a área do gráfico**, geralmente correspondendo aos eixos X e Y. Você pode ajustar as spines para melhorar a aparência do gráfico.
#
# No nosso gráfico, há quatro spines: **direita**, **esquerda**, **superior** e **inferior**.
#
# Assim como nos grids, há várias possibilidades com as spines: podemos removê-las, ou alterar suas cores, estilos e espessuras.

# %%
# Definindo os dados
x = [1, 2, 3, 4, 5, 6, 7, 8]
y = [2, 3, 5, 6, 8, 9, 11, 12]

# Criando uma figura com quatro eixos - tamanho 15x4.8 polegadas
fig, ax = plt.subplots(1, 4, figsize=(15, 4.8))

# Gráfico sem spines
ax[0].plot(x, y)
ax[0].set_xlabel("Eixo X")
ax[0].set_ylabel("Eixo Y")
ax[0].set_title("Gráfico sem spines")
# Removendo todos os spines
ax[0].spines["top"].set_visible(False)
ax[0].spines["bottom"].set_visible(False)
ax[0].spines["left"].set_visible(False)
ax[0].spines["right"].set_visible(False)

# Spines com estilo de linha
ax[1].plot(x, y)
ax[1].set_xlabel("Eixo X")
ax[1].set_ylabel("Eixo Y")
ax[1].set_title("Spines com estilo de linha")
# Definindo diferentes estilos de linha para os spines
ax[1].spines["top"].set_linestyle("--")
ax[1].spines["bottom"].set_linestyle("-.")
ax[1].spines["left"].set_linestyle(":")
ax[1].spines["right"].set_linestyle("-")

# Spines com linha mais espessa
ax[2].plot(x, y)
ax[2].set_xlabel("Eixo X")
ax[2].set_ylabel("Eixo Y")
ax[2].set_title("Spines com linha mais espessa")
# Ajustando a espessura das linhas dos spines
ax[2].spines["top"].set_linewidth(1.5)
ax[2].spines["bottom"].set_linewidth(2.5)
ax[2].spines["left"].set_linewidth(2.5)
ax[2].spines["right"].set_linewidth(1.5)

# Spines com cor
ax[3].plot(x, y)
ax[3].set_xlabel("Eixo X")
ax[3].set_ylabel("Eixo Y")
ax[3].set_title("Spines com Cor")
# Definindo cores para os spines
ax[3].spines["top"].set_color("Cyan")
ax[3].spines["bottom"].set_color("Magenta")
ax[3].spines["left"].set_color("Yellow")
ax[3].spines["right"].set_color("Gray")

# Ajustando o layout
fig.tight_layout()

# Exibindo os gráficos
plt.show()

# %% [markdown]
# ### Paletas de Cores
# Paletas de cores são essenciais para distinguir diferentes categorias de dados e destacar informações importantes. No Matplotlib, você pode utilizar paletas de cores predefinidas ou criar suas próprias paletas personalizadas.

# %% [markdown]
# #### Paletas Predefinidas
# Matplotlib oferece uma variedade de paletas de cores predefinidas, que facilitam a criação de gráficos consistentes e esteticamente agradáveis sem a necessidade de definir manualmente cada cor.

# %%
# Obtendo todas as paletas de cores disponíveis
colormaps = plt.colormaps()

print(f"Todas as paletas de cores disponíveis na biblioteca Matplotlib:\n{colormaps}")
# Out:
# Todas as paletas de cores disponíveis na biblioteca Matplotlib:
# ...

# %%
# Visualizando uma paleta de cores - Método 1
display(plt.cm.cubehelix)

# %%
# Visualizando uma paleta de cores - Método 2
gradient = np.linspace(0, 1, 256).reshape(1, -1)

plt.imshow(gradient, aspect='auto', cmap="turbo")

# %%
# Definindo os dados
x = np.random.rand(50)
y = np.random.rand(50)
c = np.random.rand(50)

# Criando uma figura com quatro eixos - tamanho 15x4.8 polegadas
fig, ax = plt.subplots(1, 4, figsize=(15, 4.8))

# Plotando o gráfico de dispersão com a paleta de cores "magma"
scatter = ax[0].scatter(x, y, c=c, cmap="magma")
ax[0].set_title("Gráfico com Paleta: magma")
fig.colorbar(scatter, ax=ax[0])

# Plotando o gráfico de dispersão com a paleta de cores "Blues"
scatter = ax[1].scatter(x, y, c=c, cmap="Blues")
ax[1].set_title("Gráfico com Paleta: Blues")
fig.colorbar(scatter, ax=ax[1])

# Plotando o gráfico de dispersão com a paleta de cores "viridis"
scatter = ax[2].scatter(x, y, c=c, cmap="viridis")
ax[2].set_title("Gráfico com Paleta: viridis")
fig.colorbar(scatter, ax=ax[2])

# Plotando o gráfico de dispersão com a paleta de cores "rainbow"
scatter = ax[3].scatter(x, y, c=c, cmap="rainbow")
ax[3].set_title("Gráfico com Paleta: rainbow")
fig.colorbar(scatter, ax=ax[3])

# Ajustando o layout
fig.tight_layout()

# Exibindo o gráfico
plt.show()

# %%
# Definindo os dados
x  = np.linspace(0, 10, 100) # Gerando 100 valores igualmente espaçados entre 0 e 10
y1 = np.sin(x) # Calculando o seno de x
y2 = np.cos(x) # Calculando o cosseno de x
y3 = np.sin(x) + np.cos(x) # Calculando a soma do seno e do cosseno

# Criando uma figura com três eixos - tamanho 15x4.8 polegadas
fig, ax = plt.subplots(1, 3, figsize=(15, 4.8))

# Plotando gráficos de linha com a paleta padrão
ax[0].plot(x, y1)
ax[0].plot(x, y2)
ax[0].plot(x, y3)
ax[0].set_title("Gráfico de Linhas - Paleta: Padrão")

# Plotando gráficos de linha com a paleta Pastel1
cores = plt.cm.Pastel1(np.linspace(0, 1, 3))

ax[1].plot(x, y1, color=cores[0])
ax[1].plot(x, y2, color=cores[1])
ax[1].plot(x, y3, color=cores[2])
ax[1].set_title("Gráfico de Linhas - Paleta: Pastel1")

# Plotando gráficos de linha com a paleta Dark2
cores = plt.cm.Dark2(np.linspace(0, 1, 3))

ax[2].plot(x, y1, color=cores[0])
ax[2].plot(x, y2, color=cores[1])
ax[2].plot(x, y3, color=cores[2])
ax[2].set_title("Gráfico de Linhas - Paleta: Dark2")

# Ajustando o layout
fig.tight_layout()

# Exibindo o gráfico
plt.show()

# %% [markdown]
# #### Paletas Personalizadas
# Além das paletas predefinidas, você pode criar paletas de cores personalizadas, oferecendo mais flexibilidade e controle sobre a aparência dos gráficos.

# %%
# Dados
x  = ["Grupo A", "Grupo B", "Grupo C", "Grupo D"]  # Definindo os rótulos para as categorias
y1 = [20, 40, 60, 80]
y2 = [35, 65, 30, 70]
y3 = [45, 55, 40, 60]
y4 = [60, 50, 75, 45]

# Criando uma figura com três eixos - tamanho 15x4.8 polegadas
fig, ax = plt.subplots(1, 3, figsize=(15, 4.8))

# Definindo Paleta de Cores Personalizadas
cores_personalizadas = ["cyan", "magenta", "yellow", "gray"]

# Plotando os gráficos de linhas - Cores Personalizadas
ax[0].plot(x, y1, marker="o", color=cores_personalizadas[0])
ax[0].plot(x, y2, marker="o", color=cores_personalizadas[1])
ax[0].plot(x, y3, marker="o", color=cores_personalizadas[2])
ax[0].plot(x, y4, marker="o", color=cores_personalizadas[3])

# Plotando o gráfico de barras - Cores Personalizadas
ax[1].bar(x, y1, color=cores_personalizadas)

# Plotando o gráfio de pizza - Cores Personalizadas
ax[2].pie(y1, labels=x, autopct="%1.1f%%", colors=cores_personalizadas)

# Definindo os Títulos dos Gráficos
ax[0].set_title("Gráfico de Linha - Paleta Personalizada")
ax[1].set_title("Gráfico de Barra - Paleta Personalizada")
ax[2].set_title("Gráfico de Pizza - Paleta Personalizada")

# Ajustando layout
fig.tight_layout()

# Exibindo os gráficos
plt.show()

# %% [markdown]
# ### Cor de Fundo (`facecolor`)
# Mudar a cor de fundo de um gráfico pode transformar totalmente a maneira como o leitor o interpreta. Esse recurso é útil para destacar informações importantes e tornar o visual mais atraente.

# %%
# Definindo os dados
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 6, 8]

# Criando uma figura com quatro eixos - tamanho 15x4.8 polegadas
fig, ax = plt.subplots(1, 4, figsize=(15, 4.8))

# Plotando o gráfico de linha - Fundo: Padrão
ax[0].plot(x, y)

# Plotando o gráfico de linha - Fundo: Cinza Claro
ax[1].plot(x, y)
ax[1].set_facecolor("lightgray") # Adicionando cor de fundo

# Plotando o gráfico de linha - Fundo: Azul Claro
ax[2].plot(x, y)
ax[2].set_facecolor("lightskyblue") # Adicionando cor de fundo

# Plotando o gráfico de linha - Personalizado
ax[3].plot(x, y, color="red") # Alterando cor da linha
ax[3].set_facecolor("azure") # Adicionando cor de fundo

# Adicionando Grid Personalizado
ax[3].grid(linestyle=":", color="lightsteelblue")

# Personalizando os Spines
ax[3].spines["top"].set_visible(False)
ax[3].spines["right"].set_visible(False)
ax[3].spines["bottom"].set_color("steelblue")
ax[3].spines["left"].set_color("steelblue")

# Adicionando o título ao gráfico
ax[0].set_title("Gráfico - Fundo: Padrão")
ax[1].set_title("Gráfico - Fundo: Cinza Claro")
ax[2].set_title("Gráfico - Fundo: Azul Claro")
ax[3].set_title("Gráfico - Personalizado")

# Ajustando layout
fig.tight_layout()

# Exibindo o gráfico
plt.show()

# %% [markdown]
# ### Personalização de Textos
#
# Adicionar informações textuais aos gráficos, como vimos anteriormente, é fundamental para melhorar a interpretação e apoiar o que está sendo exibido.
#
# Neste guia, exploramos as propriedades `set_xlabel`, `set_title`, `fig.text`, `annotate`, entre outras. Cada uma dessas informações textuais pode ser personalizada, permitindo que você ajuste fontes, estilos, cores, tamanhos, espaçamento, e mais.

# %%
# Definindo os dados
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 6, 8]

# Criando uma nova figura e um eixo
fig, ax = plt.subplots()

# Configurando a cor de fundo da figura e do eixo
fig.patch.set_facecolor("black")

# Plotando os dados
ax.plot(
    x, y, marker="o", color="red", linewidth=2,
)  # color: cor da linha, linewidth: espessura da linha

# Adicionando uma grade
ax.grid(
    color="lightgray", linestyle=":"
)  # color: cor da grade, linestyle: estilo da linha da grade

# Configurando os rótulos dos eixos
ax.set_xlabel(
    "Eixo X",
    fontsize=10,  # tamanho da fonte
    color="white",  # cor do texto
    fontname="Liberation Mono",  # nome da fonte
    fontweight="bold",  # peso da fonte (negrito)
)

ax.set_ylabel(
    "Eixo Y",
    fontsize=10,  # tamanho da fonte
    color="white",  # cor do texto
    fontname="Liberation Mono",  # nome da fonte
    fontweight="bold",  # peso da fonte (negrito)
)

# Configurando as cores das bordas
ax.spines["bottom"].set_color("white")  # cor da borda inferior
ax.spines["left"].set_color("white")  # cor da borda esquerda
ax.spines["right"].set_visible(False)  # esconder a borda direita
ax.spines["top"].set_visible(False)  # esconder a borda superior

# Configurando as cores dos ticks dos eixos
ax.tick_params(axis="x", colors="gray")  # cor dos ticks do eixo X
ax.tick_params(axis="y", colors="gray")  # cor dos ticks do eixo Y

# Adicionando um título ao gráfico
ax.set_title(
    "Gráfico com título customizado",
    backgroundcolor="white",  # cor de fundo do título
    fontfamily="monospace",  # família da fonte
    fontweight="bold",  # peso da fonte (negrito)
    fontsize=12,  # tamanho da fonte
    pad=10,  # espaçamento entre o título e o gráfico
)

# Adicionando uma anotação à figura
fig.text(
    0.361,
    0.665,
    "Essa é uma anotação com texto customizado!\nFicou legal?",
    ha="center",  # alinhamento horizontal do texto
    color="yellow",  # cor do texto
    fontname="Liberation Sans Narrow",  # nome da fonte
    fontsize=12,  # tamanho da fonte
    fontstyle="italic",  # estilo da fonte (itálico)
    linespacing=1.5,  # espaçamento entre as linhas
    backgroundcolor="black",  # cor de fundo do texto
)

# Ajustando o layout
fig.tight_layout()

# Exibindo o gráfico
plt.show()

# %% [markdown]
# ### Estilos (`plt.style.use`)
#
# Utilizar `plt.style.use` no Matplotlib é uma maneira eficiente de melhorar a aparência dos seus gráficos e economizar tempo. Veja por que você deve considerar essa funcionalidade:
#
# 1. **Economia de código**: Aplicar um estilo predefinido elimina a necessidade de configurar manualmente várias propriedades de estilo para cada gráfico, reduzindo a quantidade de código que você precisa escrever.
#
# 2. **Consistência visual**: Estilos predefinidos garantem uma aparência uniforme em todos os seus gráficos, o que é ótimo para relatórios e apresentações.
#
# 3. **Facilidade de uso**: Com `plt.style.use`, você pode alternar facilmente entre diferentes estilos para encontrar o que melhor se adapta às suas necessidades. Os estilos predefinidos ajudam a melhorar a estética dos gráficos, tornando-os mais agradáveis e fáceis de interpretar.

# %%
# Obtendo todas os estilos predefinidos disponíveis
print(f"Todos os estilos predefinidos disponíveis na biblioteca Matplotlib:\n{plt.style.available}")
# Out:
# Todos os estilos predefinidos disponíveis na biblioteca Matplotlib:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
def plotar_grafico_com_estilo(estilo):
    # Dados
    x = np.linspace(0, 10, 100)  # Gerando 100 valores igualmente espaçados entre 0 e 10
    y = np.sin(x)  # Calculando o seno de x

    # Aplicando o estilo escolhido
    plt.style.use(estilo)

    # Plotando o gráfico de linha - Aplicando estilo escolhido
    plt.plot(x, y)

    # Adicionando rótulos aos eixos X e Y
    plt.xlabel("Eixo X")
    plt.ylabel("Eixo Y")

    # Adicionando o título ao gráfico
    plt.title(f"Estilo {estilo}")

    # Exibindo os gráficos
    plt.show()

# %%
# Plotando Gráfico com estilo: Solarize_Light2
plotar_grafico_com_estilo("Solarize_Light2")

# %%
# Plotando Gráfico com estilo: seaborn-v0_8
plotar_grafico_com_estilo("seaborn-v0_8")

# %%
# Plotando Gráfico com estilo: fivethirtyeight
plotar_grafico_com_estilo("fivethirtyeight")

# %%
# Plotando Gráfico com estilo: ggplot
plotar_grafico_com_estilo("ggplot")

# %%
# Plotando Gráfico com estilo: grayscale
plotar_grafico_com_estilo("grayscale")

# %%
# Plotando Gráfico com estilo: dark_background
plotar_grafico_com_estilo("dark_background")

# %%
# Plotando Gráfico com estilo: Padrão (default)
plotar_grafico_com_estilo("default")

# %% [markdown]
# ## Gráficos 3D
#
# Gráficos 3D são ótimos para visualizar dados com uma dimensão extra. No Matplotlib, você pode criar esses gráficos utilizando o módulo `mpl_toolkits.mplot3d`.

# %%
# Importando a classe Axes3D para criar gráficos tridimensionais
from mpl_toolkits.mplot3d import Axes3D

# Definindo os dados
x = np.linspace(-5, 5, 100)  # Gerando 100 valores igualmente espaçados entre -5 e 5
y = np.linspace(-5, 5, 100)  # Gerando 100 valores igualmente espaçados entre -5 e 5
x, y = np.meshgrid(x, y)  # Criando uma grade de valores x e y
z = np.sin(
    np.sqrt(x**2 + y**2)
)  # Calculando z como o seno da raiz quadrada da soma dos quadrados de x e y

# Criando a figura e o eixo 3D, com tamanho 10x4.8 polegadas
fig = plt.figure(figsize=(10, 4.8))

# Adicionando um eixo 3D à figura
ax = fig.add_subplot(111, projection="3d")

# Plotando o gráfico de superfície 3D
surf = ax.plot_surface(
    x, y, z, cmap="ocean"
)  # Criando a superfície 3D com a paleta de cores 'ocean'

# Adicionando uma barra de cores
fig.colorbar(surf)

# Adicionando títulos e rótulos aos eixos
ax.set_title("Gráfico de Superfície 3D")
ax.set_xlabel("Eixo X")
ax.set_ylabel("Eixo Y")
ax.set_zlabel("Eixo Z")

# Ajustando o layout
fig.tight_layout()

# Exibindo o gráfico
plt.show()

# %% [markdown]
# ## Exportação de gráficos
# Os gráficos criados com o Matplotlib podem ser facilmente exportados em diversos formatos, como PNG, PDF, SVG, entre outros. Isso facilita o compartilhamento e a inclusão em documentos e relatórios.

# %%
# Definindo os dados
x = [1, 2, 3, 4, 5, 6, 7, 8]
y = [2, 3, 5, 6, 8, 9, 11, 12]

# Criando uma nova figura e um eixo
fig, ax = plt.subplots()

# Plotando o gráfico de linha no eixo ax
ax.plot(x, y)

# Adicionando rótulo ao Eixo X
ax.set_xlabel("Eixo X")

# Adicionando rótulo ao Eixo Y
ax.set_ylabel("Eixo Y")

# Definindo o título do gráfico
ax.set_title("Eu ♥ Gráficos")

# Exibindo o gráfico
plt.show()

# Exportando o gráfico para o formato PNG
fig.savefig('grafico.png')

# Exportando o gráfico para o formato PDF
fig.savefig('grafico.pdf')

# %% [markdown]
# ## Conclusão
# Neste guia, exploramos os principais **conceitos da biblioteca** Matplotlib, focando na _visualização de dados_. Agora que domina as ferramentas, está pronto para criar gráficos e visualizações incríveis!
#
# Lembre-se, o Matplotlib é uma biblioteca rica e flexível, oferecendo **muito mais do que vimos aqui**. Este guia é apenas um **ponto de partida** para você explorar mais.
#
# Espero que este material tenha sido útil e inspirador para a sua jornada de aprendizado. Não hesite em revisitá-lo sempre que **precisar de ajuda**.

# %% [markdown]
# > Divirta-se aprendendo e analisando dados! 🚀📊

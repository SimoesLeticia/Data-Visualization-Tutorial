# %% [markdown]
# # Seaborn

# %% [markdown]
# ## Introdução
#
# Bem-vindo ao nosso guia sobre **Seaborn**! O Seaborn é uma biblioteca de **visualização de dados** em **Python** conhecida por sua **simplicidade** e pelo foco em **gráficos estatísticos**. Baseada no **Matplotlib**, essa biblioteca oferece uma interface mais **sofisticada**, permitindo criar **gráficos atraentes** sem a necessidade de lidar com detalhes visuais complexos.
#
# O Seaborn integra-se perfeitamente com outras bibliotecas de ciência de dados, como o `pandas`, o que facilita a exploração e compreensão dos seus dados. Suas funções de plotagem operam diretamente em dataframes e arrays, realizando internamente o mapeamento semântico e a agregação estatística necessários para produzir **gráficos úteis e intuitivos**.
#
# Neste guia, vamos explorar desde **conceitos básicos** até diversos **tipos de gráficos** e **técnicas de personalização**. Prepare-se para descobrir como o Seaborn pode simplificar a visualização de dados e tornar suas análises mais eficazes e esteticamente agradáveis.
#
# _**Observação:** Neste guia, não abordaremos conceitos básicos sobre Matplotlib. Para acessar nosso guia completo sobre Matplotlib, clique [aqui](https://github.com/SimoesLeticia/Data-Visualization-Tutorial/blob/main/MATPLOTLIB.ipynb)._

# %% [markdown]
# ## Instalação e Configuração

# %% [markdown]
# Antes de mergulharmos no mundo fantástico do Seaborn, precisamos garantir que ele esteja instalado no seu ambiente de trabalho. Para isso, execute o seguinte comando:

# %%
# !pip install -U seaborn

# %% [markdown]
# Após a instalação ser concluída, o próximo passo é importar a biblioteca. Vamos adotar o padrão amplamente utilizado na comunidade Python, que é importar o Seaborn com o apelido (alias) `sns`. Esse hábito ajuda a manter nosso código limpo e fácil de entender.

# %%
# Importando Seaborn
import seaborn as sns

# Mostrando a versão atual do Seaborn instalada
print(sns.__version__)
# Out:
# 0.13.2

# %% [markdown]
# O Seaborn se integra perfeitamente com outras bibliotecas como `Matplotlib`, `NumPy` e `Pandas`. Para seguirmos em frente, vamos também importar essas bibliotecas, pois elas são fundamentais para o contexto do nosso guia.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# Com essas bibliotecas instaladas e importadas, estamos prontos para explorar muito do que o Seaborn pode oferecer para a visualização de dados!

# %% [markdown]
# ## Comparação com Matplotlib
# Embora o Matplotlib seja uma biblioteca poderosa e amplamente utilizada para visualização de dados, o Seaborn oferece algumas vantagens significativas, especialmente para iniciantes. Aqui estão as principais vantagens de usar o Seaborn:
#
# - **Simplicidade:** Seaborn simplifica a criação de gráficos bonitos e informativos com menos linhas de código.
# - **Estética:** Os gráficos gerados pelo Seaborn têm uma aparência moderna e agradável por padrão.
# - **Integração com Pandas:** Seaborn trabalha diretamente com DataFrames do Pandas, tornando mais fácil a plotagem de dados complexos.
# - **Facilidade de Personalização:** Seaborn oferece uma API de alto nível para personalizar gráficos, facilitando ajustes em estilos, cores e temas.

# %% [markdown]
# Vamos comparar visualmente a diferença entre um histograma gerado com Matplotlib e outro gerado com Seaborn.

# %% [markdown]
# **Histograma com Matplotlib**

# %%
# Definindo os dados
data = np.random.randn(1000)  # Gerando 1000 valores aleatórios com distribuição normal

# Plotando o histograma
plt.hist(data, bins=10)

# Adicionando o título ao gráfico
plt.title("Histograma com Matplotlib")

# Exibindo o gráfico
plt.show()

# %% [markdown]
# **Histograma com Seaborn**

# %%
# Plotando o histograma
sns.histplot(data, bins=10, kde=True)

# Adicionando o título ao gráfico
plt.title("Histograma com Seaborn")

# Exibindo o gráfico
plt.show()

# %% [markdown]
# Como você pode notar, o Seaborn oferece uma forma mais simples de plotar gráficos, exigindo menos ajustes para obter visualizações esteticamente agradáveis.

# %% [markdown]
# ## Conceitos Básicos

# %% [markdown]
# ### Primeiro Gráfico com Seaborn
# Se você já está acostumado a criar gráficos com Matplotlib, vai achar o Seaborn bem intuitivo. A principal diferença é que o Seaborn oferece uma sintaxe mais simples e várias opções de personalização por padrão. Vamos criar um gráfico de linha simples primeiro com Matplotlib e depois com Seaborn, mostrando como definir rótulos e títulos em ambos.

# %% [markdown]
# **Exemplo com Matplotlib**
#
# Primeiro, vamos criar um gráfico de linha usando Matplotlib.

# %%
# Criando dois arrays de dados
x = [1, 2, 3, 4, 5, 6, 7, 8]
y = [2, 3, 5, 6, 8, 9, 11, 12]

# Gerando o gráfico de linha com plt.plot
plt.plot(x, y)

# Adicionando rótulo ao Eixo X
plt.xlabel("Eixo X")

# Adicionando rótulo ao Eixo Y
plt.ylabel("Eixo Y")

# Definindo o título do gráfico
plt.title("Meu primeiro gráfico com Matplotlib")

# Exibindo o gráfico
plt.show()

# %% [markdown]
# **Exemplo com Seaborn**
#
# Agora, vamos criar o mesmo gráfico usando Seaborn. Note como o método `.set()` simplifica a adição de rótulos e títulos

# %%
# Criando dois arrays de dados
x = [1, 2, 3, 4, 5, 6, 7, 8]
y = [2, 3, 5, 6, 8, 9, 11, 12]

# Gerando o gráfico de linha com sns.lineplot
sns.lineplot(x=x, y=y).set(
    xlabel="Eixo X",
    ylabel="Eixo Y",
    title="Meu primeiro gráfico com Seaborn"
)

# Exibindo o gráfico
plt.show()

# %% [markdown]
# ### Múltiplos Gráficos em uma Figura
# Criar múltiplos gráficos em uma única figura é útil quando queremos comparar diferentes visualizações lado a lado. Em Seaborn, assim como em Matplotlib, usamos o parâmetro `ax` para especificar os eixos onde os gráficos serão desenhados. A diferença é que, em Seaborn, `ax` é passado diretamente como um argumento para as funções de plotagem, enquanto em Matplotlib os gráficos são desenhados a partir do objeto `ax`.

# %% [markdown]
# **Exemplo com Matplotlib**
#
# Primeiro, vamos ver como criar múltiplos gráficos em uma figura usando Matplotlib.

# %%
# Definindo os dados
x = ["Grupo A", "Grupo B", "Grupo C"]
y = [20, 40, 60]

# Criando uma figura com dois eixos - tamanho 10x4.8 polegadas
fig, ax = plt.subplots(1, 2, figsize=(10, 4.8))

# Plotando o gráfico de linha no primeiro eixo
ax[0].plot(x, y)

# Plotando o gráfico de barra no segundo eixo
ax[1].bar(x, y)

# Adicionando rótulos aos Eixos
ax[0].set_xlabel("Eixo X")
ax[0].set_ylabel("Eixo Y")
ax[1].set_xlabel("Eixo X")
ax[1].set_ylabel("Eixo Y")

# Adicionando títulos aos gráficos
ax[0].set_title("Gráfico de Linha")
ax[1].set_title("Gráfico de Barra")

# Ajustando o layout dos gráficos
fig.tight_layout()

# Exibindo os gráficos
plt.show()

# %% [markdown]
# **Exemplo com Seaborn**
#
# Agora, vamos ver como criar os mesmos gráficos usando Seaborn. Utilizaremos o parâmetro `ax` para especificar os eixos onde queremos desenhar cada gráfico:

# %%
# Definindo os dados
x = ["Grupo A", "Grupo B", "Grupo C"]
y = [20, 40, 60]

# Criando uma figura com dois eixos - tamanho 10x4.8 polegadas
fig, ax = plt.subplots(1, 2, figsize=(10, 4.8))

# Plotando o gráfico de linha no primeiro eixo
sns.lineplot(x=x, y=y, ax=ax[0]).set(
    xlabel="Eixo X",
    ylabel="Eixo Y",
    title="Gráfico de Linha"
)

# Plotando o gráfico de barra no segundo eixo
sns.barplot(x=x, y=y, ax=ax[1]).set(
    xlabel="Eixo X",
    ylabel="Eixo Y",
    title="Gráfico de Barra"
)

# Ajustando o layout dos gráficos
fig.tight_layout()

# Exibindo os gráficos
plt.show()

# %% [markdown]
# ### Gráficos com Matplotlib e Seaborn
# Podemos plotar gráficos usando tanto Matplotlib quanto Seaborn numa mesma figura. Veja o exemplo abaixo:

# %%
# Definindo os dados
data = np.random.randn(1000)

# Criando uma figura com dois eixos - tamanho 10x4.8 polegadas
fig, ax = plt.subplots(1, 2, figsize=(10, 4.8))

# Plotando o histograma com Matplotlib
ax[0].hist(data, bins=10)

# Adicionando título e rótulos ao gráfico
ax[0].set_title("Histograma com Matplotlib")
ax[0].set_xlabel("Valores")
ax[0].set_ylabel("Contagem")

# Plotando o histograma com Seaborn
sns.histplot(data, bins=10, kde=True, ax=ax[1]).set(
    xlabel="Valores",
    ylabel="Contagem",
    title="Histograma com Seaborn"
)

# Ajustando o layout dos gráficos
fig.tight_layout()

# Exibindo o gráfico
plt.show()

# %% [markdown]
# Neste exemplo, criamos uma figura com dois gráficos lado a lado, o primeiro utilizando **Matplotlib** e o segundo **Seaborn**. Ambos os gráficos exibem um **histograma dos mesmos dados**, permitindo uma **comparação** direta **entre as duas bibliotecas**.

# %% [markdown]
# ### Datasets
# Para começar a usar o Seaborn de maneira eficaz, é importante entender alguns conceitos básicos. Um dos melhores jeitos de aprender é utilizando um dataset de exemplo. O Seaborn possui vários **datasets integrados** ótimos para praticar! Para listar todos os datasets disponíveis, você pode usar o seguinte comando:

# %%
# Listando todos os datasets disponíveis no Seaborn
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %% [markdown]
# #### Dataset de Exemplo: Penguins
#
# O dataset `penguins` contém medições de três espécies de pinguins coletadas nas ilhas Palmer, na Antártica. Vamos carregar e explorar esse dataset para entender sua estrutura.

# %%
# Carregando o dataset dos pinguins
penguins = sns.load_dataset("penguins")

# Exibindo as primeiras linhas do dataset
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# #### Estrutura dos Dados
# Vamos examinar a estrutura dos dados para entender melhor o que cada coluna representa:

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# #### Descrição das Colunas
#
# - `species`: Espécie do pinguim (_Adelie, Chinstrap, Gentoo_)
# - `island`: Ilha onde o pinguim foi observado (_Biscoe, Dream, Torgersen_)
# - `bill_length_mm`: Comprimento do bico em milímetros
# - `bill_depth_mm`: Profundidade do bico em milímetros
# - `flipper_length_mm`: Comprimento da nadadeira em milímetros
# - `body_mass_g`: Massa corporal em gramas
# - `sex`: Sexo do pinguim (_male, female_)

# %% [markdown]
# ## Tipos de Gráficos
#
# O Seaborn oferece diversos tipos de gráficos para explorar e visualizar dados.
# Abaixo, veremos uma breve explicação de cada tipo de gráfico, juntamente com um código exemplo usando o **dataset dos pinguins**.

# %% [markdown]
# ### Gráficos de Dispersão (`scatterplot`)
# Mostram a relação entre duas variáveis contínuas. São úteis para visualizar correlações e padrões.

# %%
# Criando uma figura com quatro eixos - tamanho 20x4.8 polegadas
fig, axs = plt.subplots(1, 4, figsize=(20, 4.8))

# Definindo paleta de cores personalizada para as espécies
cores_personalizadas = ["#073A61", "#DA4949", "#DD9C46"]

# Filtrando os dados para a espécie Adelie e criando um scatterplot
penguins_adelie = penguins[penguins["species"] == "Adelie"]
sns.scatterplot(
    x="flipper_length_mm",
    y="body_mass_g",
    data=penguins_adelie,
    color=cores_personalizadas[0],
    marker="s",
    ax=axs[0],
).set(
    title="Gráfico de Dispersão: Adelie\nComprimento da Nadadeira vs. Massa Corporal",
    xlabel="Comprimento da nadadeira (mm)",
    ylabel="Massa corporal (g)",
)

# Filtrando os dados para a espécie Chinstrap e criando um scatterplot
penguins_chinstrap = penguins[penguins["species"] == "Chinstrap"]
sns.scatterplot(
    x="flipper_length_mm",
    y="body_mass_g",
    data=penguins_chinstrap,
    color=cores_personalizadas[1],
    marker="h",
    ax=axs[1],
).set(
    title="Gráfico de Dispersão: Chinstrap\nComprimento da Nadadeira vs. Massa Corporal",
    xlabel="Comprimento da nadadeira (mm)",
    ylabel="Massa corporal (g)",
)

# Filtrando os dados para a espécie Gentoo e criando um scatterplot
penguins_gentoo = penguins[penguins["species"] == "Gentoo"]
sns.scatterplot(
    x="flipper_length_mm",
    y="body_mass_g",
    data=penguins_gentoo,
    color=cores_personalizadas[2],
    marker="p",
    ax=axs[2],
).set(
    title="Gráfico de Dispersão: Gentoo\nComprimento da Nadadeira vs. Massa Corporal",
    xlabel="Comprimento da nadadeira (mm)",
    ylabel="Massa corporal (g)",
)

# Criando um scatterplot para todas as espécies
sns.scatterplot(
    x="flipper_length_mm",
    y="body_mass_g",
    data=penguins,
    hue="species",
    palette=cores_personalizadas,
    marker="o",
    ax=axs[3],
).set(
    title="Gráfico de Dispersão: Todas as Espécies\nComprimento da Nadadeira vs. Massa Corporal",
    xlabel="Comprimento da nadadeira (mm)",
    ylabel="Massa corporal (g)",
)

# Ajustando layout
fig.tight_layout()

# Exibindo os gráficos
plt.show()

# %% [markdown]
# ### Gráficos de Barras (barplot)
# Exibem a média de uma variável contínua para diferentes categorias, facilitando a comparação de valores entre categorias.

# %%
# Criando uma figura com três eixos - tamanho 20x4.8 polegadas
fig, axs = plt.subplots(1, 3, figsize=(20, 4.8))

# Definindo paleta de cores personalizada para as espécies
cores_personalizadas = ["#073A61", "#DA4949", "#DD9C46"]

# Definindo paleta de cores personalizada para o sexo
paleta_sexo_personalizada = {"Male": "#6DD2FC", "Female": "#FC6D85"}

# Criando gráfico de barras verticais
sns.barplot(
    x="species",
    y="body_mass_g",
    data=penguins,
    hue="species",
    palette=cores_personalizadas,
    ax=axs[0]
).set(
    title="Gráfico de Barras Verticais:\nEspécie vs. Massa Corporal Média",
    xlabel="Espécies",
    ylabel="Massa corporal média (g)"
)

# Criando gráfico de barras verticais agrupadas
sns.barplot(
    x="species",
    y="body_mass_g",
    hue="sex",
    data=penguins,
    palette=paleta_sexo_personalizada,
    ax=axs[1]
).set(
    title="Gráfico de Barras Verticais Agrupadas:\nEspécie e Sexo vs. Massa Corporal Média",
    xlabel="Espécies",
    ylabel="Massa corporal média (g)"
)

# Criando gráfico de barras horizontais
sns.barplot(
    x="flipper_length_mm",
    y="species",
    data=penguins,
    hue="species",
    palette=cores_personalizadas,
    ax=axs[2]
).set(
    title="Gráfico de Barras Horizontais:\nEspécie vs. Comprimento Médio da Nadadeira",
    xlabel="Comprimento da nadadeira (mm)",
    ylabel="Espécies"
)

# Ajustando layout
fig.tight_layout()

# Exibindo os gráficos
plt.show()

# %% [markdown]
# ### Gráficos de Linhas (lineplot)
# Usados para mostrar a evolução de uma variável ao longo do tempo ou outro eixo contínuo.

# %%
# Criando uma figura com quatro eixos - tamanho 20x4.8 polegadas
fig, axs = plt.subplots(1, 4, figsize=(20, 4.8))

# Definindo paleta de cores personalizada para as espécies
cores_personalizadas = ["#073A61", "#DA4949", "#DD9C46"]

# Criando um lineplot para Massa Corporal
sns.lineplot(
    x=penguins.index,
    y="body_mass_g",
    data=penguins,
    hue="species",
    palette=cores_personalizadas,
    ax=axs[0]
).set(
    xlabel="Índice do Dataset",
    ylabel="Massa corporal (g)",
    title="Gráfico de Linhas:\nMassa Corporal ao Longo do Índice"
)

# Criando um lineplot para Comprimento da Nadadeira
sns.lineplot(
    x=penguins.index,
    y="flipper_length_mm",
    data=penguins,
    hue="species",
    palette=cores_personalizadas,
    ax=axs[1]
).set(
    xlabel="Índice do Dataset",
    ylabel="Comprimento da nadadeira (mm)",
    title="Gráfico de Linhas:\nComprimento da Nadadeira ao Longo do Índice"
)

# Criando um lineplot para Comprimento do Bico
sns.lineplot(
    x=penguins.index,
    y="bill_length_mm",
    data=penguins,
    hue="species",
    palette=cores_personalizadas,
    ax=axs[2]
).set(
    xlabel="Índice do Dataset",
    ylabel="Comprimento do bico (mm)",
    title="Gráfico de Linhas:\nComprimento do Bico ao Longo do Índice"
)

# Criando um lineplot para Profundidade do Bico
sns.lineplot(
    x=penguins.index,
    y="bill_depth_mm",
    data=penguins,
    hue="species",
    palette=cores_personalizadas,
    ax=axs[3]
).set(
    xlabel="Índice do Dataset",
    ylabel="Profundidade do bico (mm)",
    title="Gráfico de Linhas:\nProfundidade do Bico ao Longo do Índice"
)

# Ajustando layout
fig.tight_layout()

# Exibindo os gráficos
plt.show()

# %% [markdown]
# ### Gráficos de Densidade (kdeplot)
# Estimam a distribuição de uma variável contínua usando uma curva suavizada.

# %%
# Criando uma figura com dois eixos - tamanho 20x4.8 polegadas
fig, axs = plt.subplots(1, 2, figsize=(20, 4.8))

# Definindo paleta de cores personalizada para as espécies
cores_personalizadas = ["#073A61", "#DA4949", "#DD9C46"]

# Criando um Kdeplot para Profundidade do Bico
sns.kdeplot(
    x="bill_depth_mm",
    data=penguins,
    hue="species",
    fill=True,
    palette=cores_personalizadas,
    ax=axs[0]
).set(
    xlabel="Profundidade do bico (mm)",
    ylabel="Densidade",
    title="Gráfico de Densidade: Profundidade do Bico por Espécie"
)

# Criando um Kdeplot para Comprimento do Bico
sns.kdeplot(
    x="bill_length_mm",
    data=penguins,
    hue="species",
    fill=False,
    palette=cores_personalizadas,
    ax=axs[1]
).set(
    xlabel="Comprimento do bico (mm)",
    ylabel="Densidade",
    title="Gráfico de Densidade: Comprimento do Bico por Espécie"
)

# Ajustando layout
fig.tight_layout()

# Exibindo os gráficos
plt.show()

# %% [markdown]
# ### Gráficos de Caixa (boxplot)
# Revelam a distribuição de uma variável contínua em diferentes categorias, incluindo mediana, quartis e outliers.

# %%
# Criando uma figura com dois eixos - tamanho 20x4.8 polegadas
fig, axs = plt.subplots(1, 2, figsize=(20, 4.8))

# Definindo paleta de cores personalizada para as espécies
cores_personalizadas = ["#073A61", "#DA4949", "#DD9C46"]

# Criando um Boxplot para Profundidade do Bico
sns.boxplot(
    x="species",
    y="bill_depth_mm",
    data=penguins,
    hue="species",
    fill=True,
    palette=cores_personalizadas,
    ax=axs[0],
).set(
    xlabel="Espécies",
    ylabel="Profundidade do bico (mm)",
    title="Gráfico de Caixa: Profundidade do Bico por Espécie",
)

# Criando um Boxplot para Comprimento do Bico
sns.boxplot(
    x="species",
    y="bill_length_mm",
    data=penguins,
    hue="species",
    fill=False,
    palette=cores_personalizadas,
    ax=axs[1],
).set(
    xlabel="Espécies",
    ylabel="Comprimento do bico (mm)",
    title="Gráfico de Caixa: Comprimento do Bico por Espécie",
)

# Ajustando layout
fig.tight_layout()

# Exibindo os gráficos
plt.show()

# %% [markdown]
# ### Gráficos de Violino (violinplot)
# Combinam a caixa e a densidade para ilustrar a distribuição de uma variável contínua.

# %%
# Criando uma figura com dois eixos - tamanho 20x4.8 polegadas
fig, axs = plt.subplots(1, 2, figsize=(20, 4.8))

# Definindo paleta de cores personalizada para as espécies
cores_personalizadas = ["#073A61", "#DA4949", "#DD9C46"]

# Criando um Violinplot para Profundidade do Bico
sns.violinplot(
    x="species",
    y="bill_depth_mm",
    data=penguins,
    hue="species",
    fill=True,
    palette=cores_personalizadas,
    ax=axs[0]
).set(
    xlabel="Espécies",
    ylabel="Profundidade do bico (mm)",
    title="Gráfico de Violino: Profundidade do Bico por Espécie"
)

# Criando um Violinplot para Comprimento do Bico
sns.violinplot(
    x="species",
    y="bill_length_mm",
    data=penguins,
    hue="species",
    fill=False,
    palette=cores_personalizadas,
    ax=axs[1]
).set(
    xlabel="Espécies",
    ylabel="Comprimento do bico (mm)",
    title="Gráfico de Violino: Comprimento do Bico por Espécie"
)

# Ajustando layout
fig.tight_layout()

# Exibindo os gráficos
plt.show()

# %% [markdown]
# ### Histogramas (histplot)
# Mostram a distribuição de uma variável contínua dividida em intervalos.

# %%
# Criando uma figura com quatro eixos - tamanho 20x4.8 polegadas
fig, axs = plt.subplots(1, 4, figsize=(20, 4.8))

# Definindo paleta de cores personalizada para as espécies
cores_personalizadas = ["#073A61", "#DA4949", "#DD9C46"]

# Filtrando os dados para a espécie Adelie e criando um histplot
penguins_adelie = penguins[penguins["species"] == "Adelie"]
sns.histplot(
    x="body_mass_g",
    data=penguins_adelie,
    color=cores_personalizadas[0],
    kde=True,
    ax=axs[0],
).set(
    title="Histograma\nEspécie: Adelie - Massa Corporal",
    xlabel="Massa corporal (g)",
    ylabel="Frequência",
)

# Filtrando os dados para a espécie Chinstrap e criando um scatterplot
penguins_chinstrap = penguins[penguins["species"] == "Chinstrap"]
sns.histplot(
    x="body_mass_g",
    data=penguins_chinstrap,
    color=cores_personalizadas[1],
    kde=True,
    ax=axs[1],
).set(
    title="Histograma\nEspécie: Chinstrap - Massa Corporal",
    xlabel="Massa corporal (g)",
    ylabel="Frequência",
)

# Filtrando os dados para a espécie Gentoo e criando um scatterplot
penguins_gentoo = penguins[penguins["species"] == "Gentoo"]
sns.histplot(
    x="body_mass_g",
    data=penguins_gentoo,
    color=cores_personalizadas[2],
    kde=True,
    ax=axs[2],
).set(
    title="Histograma\nEspécie: Gentoo - Massa Corporal",
    xlabel="Massa corporal (g)",
    ylabel="Frequência",
)

# Criando um scatterplot para todas as espécies
sns.histplot(
    x="body_mass_g",
    data=penguins,
    hue="species",
    palette=cores_personalizadas,
    kde=True,
    ax=axs[3],
).set(
    title="Histograma\nTodas as Espécies - Massa Corporal",
    xlabel="Massa corporal (g)",
    ylabel="Frequência",
)

# Ajustando layout
fig.tight_layout()

# Exibindo os gráficos
plt.show()

# %% [markdown]
# ### Gráficos de Calor (heatmap)
# Exibem uma matriz de valores em formato de tabela, onde as cores representam a magnitude dos valores.

# %%
# Criando uma figura com dois eixos - tamanho 20x4.8 polegadas
fig, axs = plt.subplots(1, 2, figsize=(20, 4.8))

# Filtrando apenas as variáveis numéricas
penguins_numerico = penguins.select_dtypes(include="number")

# Calculando a matriz de correlação
corr = penguins_numerico.corr()

# Calculando o valor central (média dos valores da matriz de correlação)
central_value = corr.values.mean()

# Criando o gráfico de calor (heatmap)
sns.heatmap(
    corr,
    annot=True,
    cmap="coolwarm",
    fmt=".2f",
    linewidths=0.5,
    linecolor="black",
    ax=axs[0]
).set(
    title="Gráfico de Calor: Matriz de Correlação",
    xlabel="Variáveis do Dataset",
    ylabel="Variáveis do Dataset",
)

# Criando o gráfico de calor com paleta divergente
sns.heatmap(
    corr,
    cmap="coolwarm",
    center=central_value,
    linewidths=0.5,
    linecolor="white",
    ax=axs[1]
).set(
    title="Gráfico de Calor: Paleta Divergente",
    xlabel="Variáveis do Dataset",
    ylabel="Variáveis do Dataset",
)

# Ajustando layout
fig.tight_layout()

# Exibindo os gráficos
plt.show()

# %% [markdown]
# **Observação**
#
# As *paletas de cores divergentes* são usadas para representar variáveis que sugerem oposição, com um ponto central ou neutro, permitindo que as variações ocorram em ambas as direções. São úteis em visualizações como mapas de calor, onde se deseja destacar desvios a partir de um ponto médio. Essas paletas ajudam a identificar claramente correlações negativas e positivas em torno desse ponto central.
#
# Por exemplo:
# ```
# Azul     = -1
# Branco   =  0
# Vermelho = +1
# ```

# %% [markdown]
# ### Pairplots (pairplot)
# Apresentam gráficos de dispersão para todas as combinações possíveis de variáveis em um dataset.

# %%
# Definindo paleta de cores personalizada para as espécies
cores_personalizadas = ["#073A61", "#DA4949", "#DD9C46"]

# Criando o pairplot
sns.pairplot(penguins, hue="species", palette=cores_personalizadas)

# Ajustando título
plt.suptitle("Gráfico de Dispersão em Pares por Espécie", y=1.05)

# Exibindo o gráfico
plt.show()

# %% [markdown]
# ## Personalização de Gráficos
# Uma das principais vantagens de usar a biblioteca Seaborn é sua versatilidade em relação às personalizações e customizações de gráficos. Com Seaborn, conseguimos gerar gráficos esteticamente mais bonitos com poucas linhas de código.

# %% [markdown]
# ### Títulos, Rótulos, Anotações e Legendas
# Assim como no Matplotlib, o Seaborn permite personalizar detalhes como o tamanho, estilo e cores da fonte das informações textuais dos gráficos. Podemos realizar essas personalizações de forma macro ou alterar cada elemento individualmente.
#
# Neste momento, veremos como personalizar cada elemento individualmente e, posteriormente neste tutorial, refinaremos essas personalizações.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Definindo os dados
x = [1, 2, 3, 4, 5, 6, 7, 8]
y = [2, 3, 5, 6, 8, 9, 11, 12]

# Gerando o gráfico de linha com rótulos personalizados, título e legenda
ax = sns.lineplot(x=x, y=y, linewidth=4, color="#DD9C46")
ax.set(
    xlabel="Eixo X",
    ylabel="Eixo Y",
    title="Gráfico com Título Personalizado"
)

ax.set_xlabel("Eixo X", fontsize=12, fontweight="bold", color="#DA4949")
ax.set_ylabel("Eixo Y", fontsize=12, fontweight="bold", color="#DA4949")
ax.set_title(
    "Gráfico com Título Personalizado",
    fontsize=16,
    color="#073A61",
    fontweight="bold",
    fontname="Liberation Sans Narrow",
    fontstyle="italic",
)

ax.legend(["Dados"], title="Legenda", title_fontsize="13")

# Adicionando uma anotação
ax.annotate(
    "Ponto de Interesse",
    xy=(4, 6),
    xytext=(5, 5),
    fontsize=10,
    color="#657432",
    fontweight="bold",
    arrowprops=dict(
        facecolor="#2B2A2B",
        shrink=0.05
    )
)

# Exibindo o gráfico
plt.show()

# %% [markdown]
# ### Paletas de Cores
#
# Ao criar uma visualização de dados, seu objetivo é comunicar os insights encontrados de forma clara e eficaz. O estilo e as cores escolhidas para suas visualizações podem influenciar significativamente como seu público interpreta essas informações.

# %%
# Visualizando todas as paletas de cores disponíveis
palettes = plt.colormaps()

print(palettes)
# Out:
# ['magma', 'inferno', 'plasma', 'viridis', 'cividis', 'twilight', 'twilight_shifted', 'turbo', 'Blues', 'BrBG', 'BuGn', 'BuPu', 'CMRmap', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 'PRGn', 'PiYG', 'PuBu', 'PuBuGn', 'PuOr', 'PuRd', 'Purples', 'RdBu', 'RdGy', 'RdPu', 'RdYlBu', 'RdYlGn', 'Reds', 'Spectral', 'Wistia', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd', 'afmhot', 'autumn', 'binary', 'bone', 'brg', 'bwr', 'cool', 'coolwarm', 'copper', 'cubehelix', 'flag', 'gist_earth', 'gist_gray', 'gist_heat', 'gist_ncar', 'gist_rainbow', 'gist_stern', 'gist_yarg', 'gnuplot', 'gnuplot2', 'gray', 'hot', 'hsv', 'jet', 'nipy_spectral', 'ocean', 'pink', 'prism', 'rainbow', 'seismic', 'spring', 'summer', 'terrain', 'winter', 'Accent', 'Dark2', 'Paired', 'Pastel1', 'Pastel2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 'tab20c', 'magma_r', 'inferno_r', 'plasma_r', 'viridis_r', 'cividis_r', 'twilight_r', 'twilight_shifted_r', 'turbo_r', 'Blues_r', 'BrBG_r', 'BuGn_r', 'BuPu_r', 'CMRmap_r', 'GnBu_r', 
# ...

# %% [markdown]
# Com Seaborn, você pode construir e visualizar paletas de cores personalizadas usando a função `sns.color_palette()`, que permite utilizar paletas integradas ou criar suas próprias passando uma lista de cores em qualquer formato válido do Matplotlib.
#
# Caso não especifique uma paleta ao usar `sns.color_palette()` ou `sns.set_palette()`, o Seaborn aplicará um conjunto padrão de cores.

# %%
# Paleta de Cores Padrão
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
# Paleta de Cores: viridis
sns.color_palette("viridis")
# Out:
# [(0.275191, 0.194905, 0.496005),
#  (0.212395, 0.359683, 0.55171),
#  (0.153364, 0.497, 0.557724),
#  (0.122312, 0.633153, 0.530398),
#  (0.288921, 0.758394, 0.428426),
#  (0.626579, 0.854645, 0.223353)]

# %% [markdown]
# Neste guia, você perceberá que estamos utilizando uma paleta de cores personalizada para os gráficos, atribuindo uma cor diferente para cada espécie de pinguim no nosso dataset. Veja abaixo as cores escolhidas:

# %%
# Definindo a paleta de cores personalizada
cores_personalizadas = ["#073A61", "#DA4949", "#DD9C46"]

sns.color_palette(cores_personalizadas)
# Out:
# [(0.027450980392156862, 0.22745098039215686, 0.3803921568627451),
#  (0.8549019607843137, 0.28627450980392155, 0.28627450980392155),
#  (0.8666666666666667, 0.611764705882353, 0.27450980392156865)]

# %% [markdown]
# Também podemos visualizar a paleta de cores em um mapa de calor, exibindo uma transição gradual da primeira à última cor.

# %%
def exibir_mapa_de_calor(cmap, largura=4.8, altura=1):
    # Definindo o tamanho da figura
    plt.figure(figsize=(largura, altura))

    # Criando um gradiente para o mapa de calor
    gradient = np.linspace(0, 1, 256).reshape(1, -1)

    # Plotando a imagem do mapa de calor
    plt.imshow(gradient, aspect="auto", cmap=cmap)

    # Desativando os eixos
    plt.axis("off")

    # Exibindo o gráfico
    plt.show()

# %%
# Exemplos de Paletas de Cores
exibir_mapa_de_calor("viridis")
exibir_mapa_de_calor("icefire")
exibir_mapa_de_calor("coolwarm")
exibir_mapa_de_calor("plasma")
exibir_mapa_de_calor("turbo")

# %%
from matplotlib.colors import LinearSegmentedColormap

# Exemplo de uso com uma paleta de cores personalizada
cores_personalizadas = ["#073A61", "#DA4949", "#DD9C46"]

cmap_personalizado = LinearSegmentedColormap.from_list(
    "custom_cmap", cores_personalizadas
)

# Chamando a função com o colormap personalizado
exibir_mapa_de_calor(cmap_personalizado)

# %% [markdown]
# ### Temas e Estilos
# Matplotlib é uma biblioteca altamente personalizável, mas ajustar suas configurações para obter gráficos atraentes pode ser desafiador. Para facilitar esse processo, o Seaborn oferece vários **temas predefinidos** e uma interface de alto nível para controlar a **aparência dos gráficos**. Ele oferece uma **variedade de temas e estilos** que tornam os gráficos consistentemente estéticos. Além disso, permite **ajustar o contexto** dos gráficos para diferentes finalidades, como apresentações ou relatórios.

# %% [markdown]
# #### Temas
#
# Seaborn permite aplicar temas globais que afetam todos os gráficos que você cria. Isso é feito usando a função `set_theme()`.
#
# Os cinco temas predefinidos disponíveis são: `darkgrid`, `whitegrid`, `dark`, `white` e `ticks`, cada um adequado para diferentes aplicações e preferências pessoais.

# %%
def plotar_grafico_com_estilo(estilo):
    # Dados
    x = np.linspace(0, 10, 100)  # Gerando 100 valores igualmente espaçados entre 0 e 10
    y = np.sin(x)  # Calculando o seno de x

    # Aplicando o estilo escolhido
    sns.set_theme(style=estilo)

    # Plotando o gráfico de linha - Aplicando estilo escolhido
    sns.lineplot(x=x, y=y).set(
        xlabel="Eixo X",
        ylabel="Eixo Y",
        title=f"Estilo: {estilo}"
    )

    # Exibindo os gráficos
    plt.show()

# %%
# Plotando Gráfico com estilo: darkgrid
plotar_grafico_com_estilo("darkgrid")

# %%
# Plotando Gráfico com estilo: whitegrid
plotar_grafico_com_estilo("whitegrid")

# %%
# Plotando Gráfico com estilo: dark
plotar_grafico_com_estilo("dark")

# %%
# Plotando Gráfico com estilo: white
plotar_grafico_com_estilo("white")

# %%
# Plotando Gráfico com estilo: ticks
plotar_grafico_com_estilo("ticks")

# %% [markdown]
# **Observação:** `sns.reset_defaults()` redefine as configurações de estilo para os valores padrão.

# %%
# Resetando para as configurações padrão
sns.reset_defaults()

# %% [markdown]
# #### Estilos
# A função `set_theme()` define o tema global para todos os gráficos, enquanto a função `set_style()` permite definir o estilo individual de cada gráfico presente em uma figura. Dessa forma, é possível ter gráficos com diferentes estilos dentro da mesma figura.

# %%
def plotar_grafico_com_estilo_individual(estilo):
 # Dados
    x = np.linspace(0, 10, 100)  # Gerando 100 valores igualmente espaçados entre 0 e 10
    y = np.sin(x)  # Calculando o seno de x

    # Plotando o gráfico de linha - Aplicando estilo escolhido
    sns.lineplot(x=x, y=y).set(
        xlabel="Eixo X",
        ylabel="Eixo Y",
        title=f"Estilo: {estilo}"
    )

# %%
# Criando uma figura com cinco eixos - tamanho 20x4.8 polegadas
fig = plt.figure(figsize=(20, 4.8))
gs = fig.add_gridspec(1, 5)

# Gerando o gráfico de linha para cada estilo
with sns.axes_style("darkgrid"):
    ax = fig.add_subplot(gs[0, 0])
    plotar_grafico_com_estilo_individual("darkgrid")

with sns.axes_style("whitegrid"):
    ax = fig.add_subplot(gs[0, 1])
    plotar_grafico_com_estilo_individual("whitegrid")

with sns.axes_style("dark"):
    ax = fig.add_subplot(gs[0, 2])
    plotar_grafico_com_estilo_individual("dark")

with sns.axes_style("white"):
    ax = fig.add_subplot(gs[0, 3])
    plotar_grafico_com_estilo_individual("white")

with sns.axes_style("ticks"):
    ax = fig.add_subplot(gs[0, 4])
    plotar_grafico_com_estilo_individual("ticks")

# Ajustando o layout dos gráficos
fig.tight_layout()

# Exibindo os gráficos
plt.show()

# %% [markdown]
# ### Ajustes de Contexto
# O método `sns.set_context()` é usado para definir os parâmetros que controlam o dimensionamento dos elementos do gráfico, como o tamanho dos rótulos e a espessura das linhas, sem afetar o estilo geral. Ele ajusta o `rcParams` do Matplotlib globalmente.
#
# Existem diferentes contextos, como *notebook*, *paper*, *talk* e *poster*, que ajustam esses parâmetros conforme a necessidade, como para relatórios ou apresentações. Além disso, é possível dimensionar os elementos da fonte separadamente dos outros valores como vimos anteriormente neste guia.

# %%
# Resetando para as configurações padrão
sns.reset_defaults()

# %%
def plotar_grafico_com_contexto(contexto):
    # Dados
    x = np.linspace(0, 10, 100)  # Gerando 100 valores igualmente espaçados entre 0 e 10
    y = np.sin(x)  # Calculando o seno de x

    # Aplicando o contexto escolhido
    sns.set_context(contexto)

    # Plotando o gráfico de linha - Aplicando contexto escolhido
    sns.lineplot(x=x, y=y).set(
        xlabel="Eixo X",
        ylabel="Eixo Y",
        title=f"Contexto: {contexto}"
    )

    # Exibindo os gráficos
    plt.show()

# %%
# Plotando Gráfico com contexto: notebook
plotar_grafico_com_contexto("notebook")

# %%
# Plotando Gráfico com contexto: paper
plotar_grafico_com_contexto("paper")

# %%
# Plotando Gráfico com contexto: talk
plotar_grafico_com_contexto("talk")

# %%
# Plotando Gráfico com contexto: poster
plotar_grafico_com_contexto("poster")

# %% [markdown]
# ### Combinação de Tema, Estilo e Contexto
# Você pode combinar **temas**, **estilos** e **contextos** para criar o **visual ideal** para seus gráficos. Isso permite uma personalização completa, garantindo que seus gráficos sejam não apenas **informativos**, mas também **esteticamente agradáveis** e **adequados** ao propósito da visualização de dados.

# %%
def plotar_grafico_com_personalizado(estilo, paleta, contexto):
    # Dados
    x = np.linspace(0, 10, 100)  # Gerando 100 valores igualmente espaçados entre 0 e 10
    y1 = np.sin(x)  # Calculando o seno de x
    y2 = np.cos(x)  # Calculando o cosseno de x
    y3 = np.sin(x) + np.cos(x)  # Calculando a soma do seno e do cosseno

    # Aplicando personalização escolhida
    sns.set_theme(style=estilo, palette=paleta)
    sns.set_context(contexto)

    # Criando uma figura com um eixo
    fig, ax = plt.subplots()

    # Plotando as linhas no mesmo eixo
    sns.lineplot(x=x, y=y1)
    sns.lineplot(x=x, y=y2)
    sns.lineplot(x=x, y=y3)

    # Personalizando o gráfico
    ax.set(
        xlabel="Eixo X",
        ylabel="Eixo Y",
        title=f"Estilo: {estilo}. Paleta: {paleta}. Contexto: {contexto}",
    )

    # Ajustando layout
    fig.tight_layout()

    # Exibindo o gráfico
    plt.show()

# %%
# Plotando Gráfico com Estilo: dark, paleta: Dark2_r e contexto: paper
plotar_grafico_com_personalizado("dark", "Dark2_r", "paper")

# %%
# Plotando Gráfico com Estilo: darkgrid, paleta: pastel e contexto: notebook
plotar_grafico_com_personalizado("darkgrid", "pastel", "notebook")

# %%
# Plotando Gráfico com Estilo: ticks, paleta: turbo e contexto: talk
plotar_grafico_com_personalizado("ticks", "turbo", "talk")

# %%
# Plotando Gráfico com Estilo: whitegrid, paleta: magma e contexto: poster
plotar_grafico_com_personalizado("whitegrid", "magma", "poster")

# %% [markdown]
# #### Recapitulando
# - **`set_theme()`**: Define o tema global para todos os gráficos, determinando uma base visual consistente.
# - **`set_style()`**: Define o estilo individual dos gráficos, permitindo que diferentes gráficos em uma mesma figura tenham aparências distintas.
# - **`set_context()`**: Ajusta o contexto dos gráficos para diferentes situações, como apresentações ou relatórios, alterando o dimensionamento dos elementos para melhor se adequar ao uso pretendido.
#
# Com essas ferramentas, é fácil personalizar seus gráficos com Seaborn para torná-los claros e visualmente atraentes, atendendo às suas necessidades específicas.

# %% [markdown]
# ## Conclusão
#
# Neste guia, exploramos os principais conceitos e funcionalidades da biblioteca Seaborn. Aprendemos a criar diversos tipos de gráficos, personalizar estilos e temas, além de aproveitar a integração com outras bibliotecas como Matplotlib e Pandas.
#
# Seaborn se destaca pela sua simplicidade e versatilidade, permitindo gerar gráficos esteticamente agradáveis com poucas linhas de código. Desde a criação de gráficos básicos até a personalização avançada, você agora possui as ferramentas necessárias para transformar seus dados em visualizações poderosas e intuitivas.
#
# Este guia é apenas o começo da sua jornada com Seaborn. A biblioteca oferece uma vasta gama de funcionalidades que vão além do que cobrimos aqui. Continue explorando, experimentando e aprendendo.
#
# Espero que este material tenha sido útil e inspirador. Consulte-o sempre que precisar de uma referência ou inspiração.
#
# > Divirta-se aprendendo e analisando dados! 🚀📊
